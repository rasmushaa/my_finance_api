# %%
import mlflow
import dotenv
import os
import pandas as pd

from mlflow.entities.model_registry import ModelVersion

from scripts.load_model_artifacts import load_model_artifacts

dotenv.load_dotenv()
# Out:
# True

# %%
load_model_artifacts()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 load_model_artifacts()
#
# File ~/Ohjelmointi/vscode/my_finance_api/load_model_artifacts.py:64, in load_model_artifacts()
#      56 def load_model_artifacts():
#      57     """ Load the model artifacts for the specified model and alias from MLflow Model Registry.
#      58
#      59     This function resolves the model version based on the provided alias,
#      60     downloads the model artifacts to a local directory,
#      61     and saves the model metadata for reference.
#      62     """
# ---> 64     model_version = _find_model_alias_version(MODEL_NAME, MODEL_ALIAS)
#      66     # Download the model artifacts for the resolved model version to a local directory
#      67     mlflow.artifacts.download_artifacts(
#      68         artifact_uri=model_version.source,
#      69         dst_path=DIST_PATH,
#      70     )
#
# File ~/Ohjelmointi/vscode/my_finance_api/load_model_artifacts.py:46, in _find_model_alias_version(model_name, model_alias)
#      41 if not model_versions:
#      42     raise mlflow.exceptions.MlflowException(
#      43         f"No versions found for model '{model_name}' in MLflow Model Registry."
#      44     )
# ---> 46 model_alias_version = [mv for mv in model_versions if model_alias in mv.aliases][0]
#      47 if not model_alias_version:
#      48     raise mlflow.exceptions.MlflowException(
#      49         f"No alias '{model_alias}' found for model '{model_name}' in MLflow Model Registry. Available aliases: {[alias for mv in model_versions for alias in mv.aliases]}"
#      50     )
#
# IndexError: list index out of range

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

for mv in client.search_model_versions(f"name='BankingModel-main'"):
    print(mv)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1771434553034, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1771434553034, metrics=None, model_id=None, name='BankingModel-main', params=None, run_id='9e93c558d6764d7ca46755981795dda0', run_link='', source='models:/m-2e360b0c96f34dc2ab82834dbdf6e2e5', status='READY', status_message=None, tags={'commit.sha': 'e41f78f80e5a6f6dae564689c0495f6b7b03b21d',
#  'model.architecture': 'TextCleaner->TextVevtorizer->RandomForestModel',
#  'model.features': "['amount', 'receiver']",
#  'package.version': '2.0.0'}, user_id='', version='4'>
# <ModelVersion: aliases=[], creation_timestamp=1768499476296, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1768499476296, metrics=None, model_id=None, name='BankingModel-main', params=None, run_id='122cda43499e4d01bcd14a3b5b9830b2', run_link='', source='models:/m-f837ec2ea73c4aaa8e3afa7fba783fb3', status='READY', status_message=None, tags={'git.commit.sha': '7e3738b5cc01834290b6cbbe702781bee073a687',
#  'model.architecture': 'FeatureSelector->TextCleaner->KbestTextVector->RandomForestModel',
#  'model.features': "['receiver', 'amount']",
#  'model.package.version': '1.1.4'}, user_id='', version='3'>
# <ModelVersion: aliases=[], creation_timestamp=1767698581516, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1767698581516, metrics=None, model_id=None, name='BankingModel-main', params=None, run_id='31b483bb56b2468f9acc11409f23bd16', run_link='', source='models:/m-98d44f175a544b41a40c5ec8cf4d3ba1', status='READY', status_message=None, tags={'git.commit.sha': '6f688af9dcf3ff9e0fa74df6899972a63e89dad2',
#  'model.architecture': 'FeatureSelector->TextCleaner->KbestTextVector->RandomForestModel',
#  'model.features': "['receiver', 'amount']",
#  'model.package.version': '1.1.3'}, user_id='', version='2'>
# <ModelVersion: aliases=[], creation_timestamp=1767697460416, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1767697460416, metrics=None, model_id=None, name='BankingModel-main', params=None, run_id='b57f4f73e17d441682b99588ab5c2a4a', run_link='', source='models:/m-34eea414e5eb45afa4b04e53e2644920', status='READY', status_message=None, tags={'git.commit.sha': 'fcb87780f7d1c4c44076c910a87c96bd500f3062',
#  'model.architecture': 'FeatureSelector->TextCleaner->KbestTextVector->RandomForestModel',
#  'model.features': "['receiver', 'amount']",
#  'model.package.version': '1.1.2'}, user_id='', version='1'>

# %%
mv = client.get_model_version_by_alias("BankingModel-main", "prod")
print(mv)
print(mv.aliases)
# Out:
# <ModelVersion: aliases=['prod', 'stg'], creation_timestamp=1771434553034, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1771434553034, metrics=None, model_id=None, name='BankingModel-main', params=None, run_id='9e93c558d6764d7ca46755981795dda0', run_link='', source='models:/m-2e360b0c96f34dc2ab82834dbdf6e2e5', status='READY', status_message=None, tags={'commit.sha': 'e41f78f80e5a6f6dae564689c0495f6b7b03b21d',
#  'model.architecture': 'TextCleaner->TextVevtorizer->RandomForestModel',
#  'model.features': "['amount', 'receiver']",
#  'package.version': '2.0.0'}, user_id='', version='4'>
# ['prod', 'stg']

# %%
mv = client.get_model_version(
        name='BankingModel-main',
        version='1',
    )
print(mv)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1767697460416, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1767697460416, metrics=None, model_id=None, name='BankingModel-main', params=None, run_id='b57f4f73e17d441682b99588ab5c2a4a', run_link='', source='models:/m-34eea414e5eb45afa4b04e53e2644920', status='READY', status_message=None, tags={'git.commit.sha': 'fcb87780f7d1c4c44076c910a87c96bd500f3062',
#  'model.architecture': 'FeatureSelector->TextCleaner->KbestTextVector->RandomForestModel',
#  'model.features': "['receiver', 'amount']",
#  'model.package.version': '1.1.2'}, user_id='', version='1'>

# %%
model = mlflow.pyfunc.load_model("models:/BankingModel-main/1")
# Out:
# 2026/02/28 20:39:04 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 3.6.0, required: mlflow==3.8.1)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = mlflow.pyfunc.load_model("models:/BankingModel-main/1")
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/mlflow/tracing/provider.py:616, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     614 try:
#     615     is_func_called = True
# --> 616     result = f(*args, **kwargs)
#     617 finally:
#     618     enable()
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py:1185, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1177     if conf[MAIN] == _DATABRICKS_FS_LOADER_MODULE and e.name.startswith("databricks"):
#    1178         raise MlflowException(
#    1179             f"{e.msg}; "
#    1180             "Note: mlflow.pyfunc.load_model is not supported for Feature Store models. "
#    (...)   1183             BAD_REQUEST,
#    1184         ) from None
# -> 1185     raise e
#    1186 finally:
#    1187     # clean up the dependencies schema which is set to global state after loading the model.
#    1188     # This avoids the schema being used by other models loaded in the same process.
#    1189     _clear_dependencies_schemas()
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py:1170, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1168         model_impl = importlib.import_module(conf[MAIN])._load_pyfunc(data_path, model_config)
#    1169     else:
# -> 1170         model_impl = importlib.import_module(conf[MAIN])._load_pyfunc(data_path)
#    1171 except ModuleNotFoundError as e:
#    1172     # This error message is particularly for the case when the error is caused by module
#    1173     # "databricks.feature_store.mlflow_model". But depending on the environment, the offending
#    1174     # module might be "databricks", "databricks.feature_store" or full package. So we will
#    1175     # raise the error with the following note if "databricks" presents in the error. All non-
#    1176     # databricks module errors will just be re-raised.
#    1177     if conf[MAIN] == _DATABRICKS_FS_LOADER_MODULE and e.name.startswith("databricks"):
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/mlflow/pyfunc/loaders/code_model.py:21, in _load_pyfunc(local_path, model_config)
#      20 def _load_pyfunc(local_path: str, model_config: dict[str, Any] | None = None):
# ---> 21     context, model, signature = _load_context_model_and_signature(local_path, model_config)
#      22     if isinstance(model, ChatModel):
#      23         return _ChatModelPyfuncWrapper(model, context, signature)
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/mlflow/pyfunc/model.py:1294, in _load_context_model_and_signature(model_path, model_config)
#    1289     artifacts[saved_artifact_name] = os.path.join(
#    1290         model_path, saved_artifact_info[CONFIG_KEY_ARTIFACT_RELATIVE_PATH]
#    1291     )
#    1293 context = PythonModelContext(artifacts=artifacts, model_config=model_config)
# -> 1294 python_model.load_context(context=context)
#    1296 return context, python_model, signature
#
# File /var/folders/5q/h1qn2hcn7k7g6khbskw6v9240000gn/T/tmpuux92jv0/wrapper.py:22, in ModelWrapper.load_context(self, context)
#      15 def load_context(self, context):
#      16     """Load model and preprocessors from artifacts.
#      17
#      18     Inputs:
#      19     context: dict
#      20         MLflow model context with artifacts paths.
#      21     """
# ---> 22     self.__pipeline = joblib.load(context.artifacts["pipeline"])
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
#     753                 mmap_mode=validated_mmap_mode,
#     754             )
#     756 return obj
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/joblib/numpy_pickle.py:626, in _unpickle(fobj, ensure_native_byte_order, filename, mmap_mode)
#     624 obj = None
#     625 try:
# --> 626     obj = unpickler.load()
#     627     if unpickler.compat_mode:
#     628         warnings.warn(
#     629             "The file '%s' has been generated with a "
#     630             "joblib version less than 0.10. "
#    (...)    633             stacklevel=3,
#     634         )
#
# File /usr/local/Cellar/python@3.11/3.11.14/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File /usr/local/Cellar/python@3.11/3.11.14/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pickle.py:1538, in _Unpickler.load_stack_global(self)
#    1536 if type(name) is not str or type(module) is not str:
#    1537     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1538 self.append(self.find_class(module, name))
#
# File /usr/local/Cellar/python@3.11/3.11.14/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pickle.py:1580, in _Unpickler.find_class(self, module, name)
#    1578     elif module in _compat_pickle.IMPORT_MAPPING:
#    1579         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1580 __import__(module, level=0)
#    1581 if self.proto >= 4:
#    1582     return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'polymodel.transformer'
