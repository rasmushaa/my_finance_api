# %%
import mlflow
import dotenv
import os
import pandas as pd
from load_model_artifacts import load_model_artifacts

dotenv.load_dotenv()
# Out:
# True

# %%
load_model_artifacts()

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

# %%
mv = client.get_model_version(
        name='BankingModel-main',
        version='1',
    )

# %%
os.environ["GCLOUD_PROJECT"] = "rasmus-prod"

# %%
dotenv.load_dotenv()
mlflow.set_tracking_uri(os.getenv('MLFLOW_TRACKING_URI'))

# %%
mlflow.load

# %%
mlflow.pyfunc.get_model_dependencies("models:/BankingModel-main/1")
# Out:
# 2026/01/10 14:49:19 INFO mlflow.pyfunc: To install the dependencies that were used to train the model, run the following command: '%pip install -r /var/folders/5q/h1qn2hcn7k7g6khbskw6v9240000gn/T/tmplfaery96/requirements.txt'.
# '/var/folders/5q/h1qn2hcn7k7g6khbskw6v9240000gn/T/tmplfaery96/requirements.txt'

# %%
model = mlflow.pyfunc.load_model("models:/BankingModel-main/1")
# Out:
# 2026/01/10 14:42:34 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 3.6.0, required: mlflow==3.8.1)
#  - polymodel (current: uninstalled, required: polymodel@ file://{ARTIFACT_PATH}/polymodel-1.1.2-py3-none-any.whl)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = mlflow.pyfunc.load_model("models:/BankingModel-main/1")
#
# File ~/Ohjelmointi/vscode/my_finance_api/.venv/lib/python3.11/site-packages/mlflow/tracing/provider.py:616, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     614 try:
#     615     is_func_called = True
# ...
